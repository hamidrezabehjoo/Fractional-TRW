# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
os.getcwd()
# Out:
# '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration'

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration/out'
os.chdir(path)
os.getcwd()

files = os.listdir(path)
for file in files:
    print(file)
# Out:
# 10
# Z.pdf
# 30
# 20
# 40

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration/out/10'
os.chdir(path)

t = np.linspace(0,1,21)

Z1 = np.loadtxt('Z1.txt')
f1 = interp1d(Z1, t)
z1 = 417.2351
t1 = f1(z1)

Z2 = np.loadtxt('Z2.txt')
f2 = interp1d(Z2, t)
z2 = 419.1974
t2 = f2(z2)

Z3 = np.loadtxt('Z3.txt')
f3 = interp1d(Z3, t)
z3 = 416.2347
t3 = f3(z3)

Z4 = np.loadtxt('Z4.txt')
f4 = interp1d(Z4, t)
z4 = 416.8475
t4 = f4(z4)




fig, ax1 = plt.subplots(figsize=(6, 4))
ax1.plot(t,Z1,'og', linestyle='solid', lw='2')
ax1.plot(t1,z1,'og', markersize=8, markerfacecolor='white')

ax1.plot(t,Z2,'sr', linestyle='solid', lw='2')
ax1.plot(t2,z2,'sr', markersize=8, markerfacecolor='white')

ax1.plot(t,Z3,'vb', linestyle='solid', lw='2')
ax1.plot(t3,z3,'vb', markersize=8, markerfacecolor='white')

ax1.plot(t,Z4,'dk', linestyle='solid', lw='2')
ax1.plot(t4,z4,'dk', markersize=8, markerfacecolor='white')

ax1.set_ylabel("$\log Z^{(\lambda)}$", fontsize=14)
ax1.set_xlabel("$\lambda$", fontsize=14)
ax1.set_xlim([0, 1])
plt.savefig('planar_graph.pdf')

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration/out/20'
os.chdir(path)

Z1 = np.loadtxt('Z1.txt')
f1 = interp1d(Z1, t)
z1 = 1725.2367
t1 = f1(z1)

Z2 = np.loadtxt('Z2.txt')
f2 = interp1d(Z2, t)
z2 = 1728.4967
t2 = f2(z2)

Z3 = np.loadtxt('Z3.txt')
f3 = interp1d(Z3, t)
z3 = 1721.5821
t3 = f3(z3)

Z4 = np.loadtxt('Z4.txt')
f4 = interp1d(Z4, t)
z4 = 1712.5849
t4 = f4(z4)




fig, ax1 = plt.subplots(figsize=(6, 4))
ax1.plot(t,Z1,'og', linestyle='solid', lw='2')
ax1.plot(t1,z1,'og', markersize=8, markerfacecolor='white')

ax1.plot(t,Z2,'sr', linestyle='solid', lw='2')
ax1.plot(t2,z2,'sr', markersize=8, markerfacecolor='white')

ax1.plot(t,Z3,'vb', linestyle='solid', lw='2')
ax1.plot(t3,z3,'vb', markersize=8, markerfacecolor='white')

ax1.plot(t,Z4,'dk', linestyle='solid', lw='2')
ax1.plot(t4,z4,'dk', markersize=8, markerfacecolor='white')

ax1.set_ylabel("$\log Z^{(\lambda)}$", fontsize=14)
ax1.set_xlabel("$\lambda$", fontsize=14)
ax1.set_xlim([0, 1])
plt.savefig('planar_graph.pdf')

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration/out/30'
os.chdir(path)

Z1 = np.loadtxt('Z1.txt')
f1 = interp1d(Z1, t)
z1 = 3950.1423
t1 = f1(z1)

Z2 = np.loadtxt('Z2.txt')
f2 = interp1d(Z2, t)
z2 = 3920.8205
t2 = f2(z2)

Z3 = np.loadtxt('Z3.txt')
f3 = interp1d(Z3, t)
z3 = 3933.7951
t3 = f3(z3)

Z4 = np.loadtxt('Z4.txt')
f4 = interp1d(Z4, t)
z4 = 3885.0058
t4 = f4(z4)




fig, ax1 = plt.subplots(figsize=(6, 4))
ax1.plot(t,Z1,'og', linestyle='solid', lw='2')
ax1.plot(t1,z1,'og', markersize=8, markerfacecolor='white')

ax1.plot(t,Z2,'sr', linestyle='solid', lw='2')
ax1.plot(t2,z2,'sr', markersize=8, markerfacecolor='white')

ax1.plot(t,Z3,'vb', linestyle='solid', lw='2')
ax1.plot(t3,z3,'vb', markersize=8, markerfacecolor='white')

ax1.plot(t,Z4,'dk', linestyle='solid', lw='2')
ax1.plot(t4,z4,'dk', markersize=8, markerfacecolor='white')

ax1.set_ylabel("$\log Z^{(\lambda)}$", fontsize=14)
ax1.set_xlabel("$\lambda$", fontsize=14)
ax1.set_xlim([0, 1])
plt.savefig('planar_graph.pdf')

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/concentration/out/40'
os.chdir(path)

Z1 = np.loadtxt('Z1.txt')
f1 = interp1d(Z1, t)
z1 = 6945.8514
t1 = f1(z1)

Z2 = np.loadtxt('Z2.txt')
f2 = interp1d(Z2, t)
z2 = 6946.10307
t2 = f2(z2)

Z3 = np.loadtxt('Z3.txt')
f3 = interp1d(Z3, t)
z3 = 6957.80307
t3 = f3(z3)

Z4 = np.loadtxt('Z4.txt')
f4 = interp1d(Z4, t)
z4 = 6948.0048
t4 = f4(z4)




fig, ax1 = plt.subplots(figsize=(6, 4))
ax1.plot(t,Z1,'og', linestyle='solid', lw='2')
ax1.plot(t1,z1,'og', markersize=8, markerfacecolor='white')

ax1.plot(t,Z2,'sr', linestyle='solid', lw='2')
ax1.plot(t2,z2,'sr', markersize=8, markerfacecolor='white')

ax1.plot(t,Z3,'vb', linestyle='solid', lw='2')
ax1.plot(t3,z3,'vb', markersize=8, markerfacecolor='white')

ax1.plot(t,Z4,'dk', linestyle='solid', lw='2')
ax1.plot(t4,z4,'dk', markersize=8, markerfacecolor='white')

ax1.set_ylabel("$\log Z^{(\lambda)}$", fontsize=14)
ax1.set_xlabel("$\lambda$", fontsize=14)
ax1.set_xlim([0, 1])
plt.savefig('planar_graph.pdf')
