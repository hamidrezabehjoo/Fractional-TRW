# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
os.getcwd()
# Out:
# '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/convergence'

# %%
path = '/home/hamidreza/Dropbox/My Research/ICML 2023/Fractional-TRW/convergence/out6'
os.chdir(path)
#os.getcwd()

files = os.listdir(path)
for file in files:
    print(file)
# Out:
# C.txt
# Z.txt

# %%
C = np.loadtxt('C.txt')
C.shape[0] / 6
# Out:
# 21.0

# %%
grid_size = 10

N = [10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7 ]

z1 = [-1.2, -1.0, -0.75, -0.5, -0.55, -0.5, -0.52]
z2 = [-1.1,  1.0, -0.55, 0.15, 0.1, 0.05, 0.02]
z3 = [-0.6, -0, 0.65, 0.6, 0.5, 0.55, 0.55]
z4 = [0.86, 0.5, 0.65, 0.76, 0.8, 0.7, 0.71]
z5 = [-0.35, 0.45, 0.95, 0.86, 0.75, 0.79, 0.81]

plt.figure(figsize=(6, 4))
plt.plot(N,z1,'-o', label="$\lambda =0.1$", lw=2)
plt.plot(N,z2,'-s', label="$\lambda =0.3$", lw=2)
plt.plot(N,z3,'-v', label="$\lambda =0.5$", lw=2)
plt.plot(N,z4,'-d', label="$\lambda =0.7$", lw=2)
plt.plot(N,z5,'-p', label="$\lambda =0.7$", lw=2)


plt.xscale('log')
#plt.xlim([10**1, 10**7])
plt.legend()
        
#plt.grid()
plt.ylabel("$\log {\mathcal{Z}}^{(\lambda)}$", fontsize=14)
plt.xlabel("$M$", fontsize=14)
plt.savefig("a.pdf", format="pdf", bbox_inches="tight" )
